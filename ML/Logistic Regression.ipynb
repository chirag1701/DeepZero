# %% [markdown]
# ## This is the code for Logistic Regression

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
def sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
make_classification
# Out:
# <function sklearn.datasets._samples_generator.make_classification(n_samples=100, n_features=20, *, n_informative=2, n_redundant=2, n_repeated=0, n_classes=2, n_clusters_per_class=2, weights=None, flip_y=0.01, class_sep=1.0, hypercube=True, shift=0.0, scale=1.0, shuffle=True, random_state=None)>

# %%
dataset = make_classification(n_samples = 100, n_features = 2, n_informative = 2, n_redundant = 0,random_state = 96)

# %%
X,y = dataset

# %%
df = pd.DataFrame({"X1":X[:,0], "X2":X[:,1],"Y":y})

# %%
df
# Out:
#           X1        X2  Y
# 0  -1.522742 -0.984186  0
# 1   0.129359 -1.154900  0
# 2   0.322663 -0.786456  0
# 3  -0.083325  1.290169  1
# 4   1.296970 -1.184195  0
# ..       ...       ... ..
# 95  0.573577 -0.828231  0
# 96  1.948022  0.715708  1
# 97 -0.185177  1.597424  1
# 98 -0.857755  1.439154  1
# 99 -1.509827  0.540144  1
#
# [100 rows x 3 columns]

# %%
plt.scatter(df["X1"],df["X2"],c=y,cmap = 'bwr')

# %%
X = np.hstack((X,np.ones((100,1))))

# %%
W = np.array([1.0,1.0,1.0])
y_pred = sigmoid(np.dot(X,W))
epochs = 1000
lr = 0.01
for i in range(epochs):
    y_pred = sigmoid(np.dot(X,W))
    W += (0.01 /len(X))*np.dot(y-y_pred,X)
print(W)
# Out:
# [0.20708044 2.45339842 0.51279252]

# %%
plt.scatter(df["X1"],df["X2"],c=y,cmap = 'bwr')
x_vals = np.array([-3,3])
y_vals = (-W[2]-W[0]*x_vals)/W[1]
plt.plot(x_vals,y_vals,'--k')
plt.show()

# %%
W
# the eq of line is of form W[0]x + W[1]y + W[2] = 0
# Out:
# array([0.20708044, 2.45339842, 0.51279252])
